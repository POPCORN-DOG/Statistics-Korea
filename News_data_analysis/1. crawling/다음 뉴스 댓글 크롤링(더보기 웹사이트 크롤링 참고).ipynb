# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup  #크롤링 필수 패키지 설치하려면 cmd창에서 pip install bs4
from tqdm import tqdm
import json
import requests

# %%
header = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 Edg/86.0.622.63"
}

r = requests.get('https://comment.daum.net/apis/v1/posts/150429570/comments?parentId=0&offset=0&limit=100&sort=CHRONOLOGICAL&isInitial=true&hasNext=true',
                 verify = False, headers = header)


soup = BeautifulSoup(r.text,'lxml')
soup
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comment.daum.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...

# %%
a = soup.select('body')[0].text
a
# Out:
# '[{"id":604505181,"userId":7582965,"postId":150429570,"forumId":-99,"parentId":0,"type":"COMMENT","status":"S","flags":256,"rating":0,"content":"참치 대가리 값도 못하노","createdAt":"2020-11-11T13:58:48+0900","updatedAt":"2020-11-11T13:58:48+0900","childCount":6,"likeCount":69,"dislikeCount":8,"recommendCount":61,"screenedByKeeper":false,"user":{"id":7582965,"status":"S","type":"USER","flags":0,"icon":"https://t1.daumcdn.net/profile/ToQniXTDJQI0","url":"","username":"DAUM:2A565","roles":"ROLE_USER,ROLE_DAUM,ROLE_IDENTIFIED","providerId":"DAUM","providerUserId":"2A565","displayName":"bingo","description":"","commentCount":526}},{"id":604505885,"userId":-33015428,"postId":150429570,"forumId":-99,"parentId":0,"type":"COMMENT","status":"S","flags":256,"rating":0,"content":"문재앙.","createdAt":"2020-11-11T14:00:59+0900","updatedAt":"2020-11-11T14:00:59+0900","childCount":8,"likeCount":9,"dislikeCount":51,"recommendCount":-42,"screenedByKeeper":false,"user":{"id":-33015428,"status":"S","type":"USER","
# ...

# %%
json.loads(a)
# Out:
# [{'id': 604505181,
#   'userId': 7582965,
#   'postId': 150429570,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 256,
#   'rating': 0,
#   'content': '참치 대가리 값도 못하노',
#   'createdAt': '2020-11-11T13:58:48+0900',
#   'updatedAt': '2020-11-11T13:58:48+0900',
#   'childCount': 6,
#   'likeCount': 69,
#   'dislikeCount': 8,
#   'recommendCount': 61,
#   'screenedByKeeper': False,
#   'user': {'id': 7582965,
#    'status': 'S',
#    'type': 'USER',
#    'flags': 0,
#    'icon': 'https://t1.daumcdn.net/profile/ToQniXTDJQI0',
#    'url': '',
#    'username': 'DAUM:2A565',
#    'roles': 'ROLE_USER,ROLE_DAUM,ROLE_IDENTIFIED',
#    'providerId': 'DAUM',
#    'providerUserId': '2A565',
#    'displayName': 'bingo',
#    'description': '',
#    'commentCount': 526}},
#  {'id': 604505885,
#   'userId': -33015428,
#   'postId': 150429570,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 256,
# ...

# %%
json.loads(a)[0]
# Out:
# {'id': 604505181,
#  'userId': 7582965,
#  'postId': 150429570,
#  'forumId': -99,
#  'parentId': 0,
#  'type': 'COMMENT',
#  'status': 'S',
#  'flags': 256,
#  'rating': 0,
#  'content': '참치 대가리 값도 못하노',
#  'createdAt': '2020-11-11T13:58:48+0900',
#  'updatedAt': '2020-11-11T13:58:48+0900',
#  'childCount': 6,
#  'likeCount': 69,
#  'dislikeCount': 8,
#  'recommendCount': 61,
#  'screenedByKeeper': False,
#  'user': {'id': 7582965,
#   'status': 'S',
#   'type': 'USER',
#   'flags': 0,
#   'icon': 'https://t1.daumcdn.net/profile/ToQniXTDJQI0',
#   'url': '',
#   'username': 'DAUM:2A565',
#   'roles': 'ROLE_USER,ROLE_DAUM,ROLE_IDENTIFIED',
#   'providerId': 'DAUM',
#   'providerUserId': '2A565',
#   'displayName': 'bingo',
#   'description': '',
#   'commentCount': 526}}

# %%
json.loads(a)[80]['content']
# Out:
# '키로당 2만원 꼴... 소고기 부럽지 않네...'

# %%
'''
url 주소창에 offset 과 limit으로 댓글 수 조절 가능 하다. 
하지만 인터넷 url 창과 실제 requests.get할때 쓰이는 url이 달라 반복해서 댓글을 수집할 수 없는 상황이다.

-> url 에서 힌트를 찾아본다 
https://comment.daum.net/apis/v1/posts/150429570/comments?parentId=0&offset=3&limit=10&sort=CHRONOLOGICAL&isInitial=false&hasNext=true

150429570라는 숫자가 key일것 같다는 느낌

-> 네트워크 검색에서 150429570 숫자 검색하니 뭐가 나옴 
https://comment.daum.net/apis/v1/ui/single/main/@20201111092437039
이 url의 뒤에가 지금 보이는 url의 뒤와 일치 

-> 한번 해보기
'''

# %%
og_url = 'https://news.v.daum.net/v/20201111092437039'

#뒤에 숫자 추출
import re
og_url_num = re.findall('\d+', og_url)[0]

#key number를 가져오기 위한 url 만들기

r2 = requests.get('https://comment.daum.net/apis/v1/ui/single/main/@' + og_url_num,
                 verify = False, headers = header)

soup2 = BeautifulSoup(r2.text,'lxml')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comment.daum.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
a2 = soup2.select('body')[0].text
a2 #unauthorizedFull authentication is required to access this resource 라는 오류가 나옴 그래서 네트워크에 헤더에서 버번 가져와야함
# Out:
# 'unauthorizedFull authentication is required to access this resource'

# %%
header2 = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 Edg/86.0.622.63",
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..R6jwvBgsfE7-LnJOIiJjfWNqbqe5_LvsH3ohatqIuiU'
}

#key number를 가져오기 위한 url 만들기 다시만들기 

r2 = requests.get('https://comment.daum.net/apis/v1/ui/single/main/@' + og_url_num,
                 verify = False, headers = header2)

soup2 = BeautifulSoup(r2.text,'lxml')

a2 = soup2.select('body')[0].text
a2 #성공

# Authorization은 24시간 마다 바뀜 그래서 하루 넘겨서 돌리기 현재로서 불가
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comment.daum.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '{"post":{"id":150429570,"forumId":-99,"postKey":"20201111092437039","flags":0,"title":"120kg짜리 심해어 돗돔 부산공동어시장서 270만원 낙찰","url":"https://news.v.daum.net/v/AAw6m7YVsC","icon":"https://img1.daumcdn.net/thumb/S1200x630/?fname=https://t1.daumcdn.net/news/202011/11/yonhap/20201111092439165eper.jpg","commentCount":415,"childCount":120,"popularOpened":true}}'

# %%
#키 찾기
postid =  json.loads(a2)['post']['id']
postid
# Out:
# 150429570

# %%
# 키 찾아서 요청 url 만들기
header = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 Edg/86.0.622.63"
}


r3 = requests.get('https://comment.daum.net/apis/v1/posts/' + str(postid) + '/comments?parentId=0&offset=0&limit=100&sort=CHRONOLOGICAL&isInitial=true&hasNext=true',
                 verify = False, headers = header)

soup3 = BeautifulSoup(r3.text,'lxml')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'comment.daum.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
a3 = soup3.select('body')[0].text

# %%
json.loads(a3)[0]
# Out:
# {'id': 604505181,
#  'userId': 7582965,
#  'postId': 150429570,
#  'forumId': -99,
#  'parentId': 0,
#  'type': 'COMMENT',
#  'status': 'S',
#  'flags': 256,
#  'rating': 0,
#  'content': '참치 대가리 값도 못하노',
#  'createdAt': '2020-11-11T13:58:48+0900',
#  'updatedAt': '2020-11-11T13:58:48+0900',
#  'childCount': 5,
#  'likeCount': 98,
#  'dislikeCount': 8,
#  'recommendCount': 90,
#  'screenedByKeeper': False,
#  'user': {'id': 7582965,
#   'status': 'S',
#   'type': 'USER',
#   'flags': 0,
#   'icon': 'https://t1.daumcdn.net/profile/ToQniXTDJQI0',
#   'url': '',
#   'username': 'DAUM:2A565',
#   'roles': 'ROLE_USER,ROLE_DAUM,ROLE_IDENTIFIED',
#   'providerId': 'DAUM',
#   'providerUserId': '2A565',
#   'displayName': 'bingo',
#   'description': '',
#   'commentCount': 526}}

# %%
json.loads(a3)[80]['content']
# Out:
# '헐~엄청난 사이즈~ 그럼 우리나라도 이제 열대성기후? 엄청나게 큰 물고기들이 몰려오는건가?'
