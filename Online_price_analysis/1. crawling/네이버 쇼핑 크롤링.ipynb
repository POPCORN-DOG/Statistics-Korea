# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup  #크롤링 필수 패키지 설치하려면 cmd창에서 pip install bs4
from tqdm import tqdm
import json
import requests

# %%
header = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 Edg/86.0.622.63"
}

r = requests.get('https://search.shopping.naver.com/search/all?query=%EB%A7%88%EC%8A%A4%ED%81%AC&cat_id=&frm=NVSHATC', verify = False, headers = header)


BeautifulSoup(r.text,'lxml')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'search.shopping.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <!DOCTYPE html>
# ...

# %%
soup =  BeautifulSoup(r.text,'lxml')
a2 = soup.select('body > script')[0].text
a2
# Out:
# '{"props":{"initialProps":{"pageProps":{},"ogTag":{"title":"마스크 : 네이버 쇼핑","image":"https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png","description":"\'마스크\'의 네이버쇼핑 검색 결과입니다"}},"initialState":{"bucketId":"","autocomplete":{"isOpen":false,"isActive":true,"typedKeyword":"","currentKeyword":"","currentIndex":-1,"lndURL":"","suggestions":{"totalCount":0}},"category":{"isOpen":false,"selected":"WEAR"},"products":{"list":[],"total":0},"groceryFilters":[],"mainFilters":[],"subFilters":[],"selectedFilters":[],"searchParam":{"query":"","origQuery":"","sort":"rel","pagingIndex":1,"pagingSize":40,"viewType":"list","productSet":"total","timestamp":"","catId":""},"searchBanInfo":{},"aside":{"luckyToday":null,"plan":null,"popularKeywords":null,"popularKeywordsByQuery":null,"popularBrands":null,"popularShoppingMalls":null,"totalCards":0},"nClick":{"susVal":"","pageUid":"","code":"","codeType":"nsc"},"userInfo":{"nickName":"유저","isAdultUser":false,"isValidMembership":false},"p
# ...

# %%
type(a2)
# Out:
# str

# %%
import json

# %%
json.loads(a2)
# Out:
# {'props': {'initialProps': {'pageProps': {},
#    'ogTag': {'title': '마스크 : 네이버 쇼핑',
#     'image': 'https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png',
#     'description': "'마스크'의 네이버쇼핑 검색 결과입니다"}},
#   'initialState': {'bucketId': '',
#    'autocomplete': {'isOpen': False,
#     'isActive': True,
#     'typedKeyword': '',
#     'currentKeyword': '',
#     'currentIndex': -1,
#     'lndURL': '',
#     'suggestions': {'totalCount': 0}},
#    'category': {'isOpen': False, 'selected': 'WEAR'},
#    'products': {'list': [], 'total': 0},
#    'groceryFilters': [],
#    'mainFilters': [],
#    'subFilters': [],
#    'selectedFilters': [],
#    'searchParam': {'query': '',
#     'origQuery': '',
#     'sort': 'rel',
#     'pagingIndex': 1,
#     'pagingSize': 40,
#     'viewType': 'list',
#     'productSet': 'total',
#     'timestamp': '',
#     'catId': ''},
#    'searchBanInfo': {},
#    'aside': {'luckyToday': None,
#     'plan': None,
# ...

# %%
json.loads(a2)['props']['pageProps']['initialState']['products']['list']
# Out:
# [{'item': {'collection': 'product',
#    'purchaseConditionInfos': None,
#    'rank': '6',
#    'adId': 'nad-a001-02-000000101467780',
#    'id': '82580461253',
#    'parentId': '82580461253',
#    'productTitle': '국산 식약처인증 KF-AD 비말차단마스크 개별포장 일회용 화이트 블랙 대형 50매',
#    'mallName': '라스트무버',
#    'isBrandStore': '0',
#    'isNaverPay': '1',
#    'isMblNaverPay': '1',
#    'nPayPcType': '2',
#    'nPayMblType': '2',
#    'saleTp': '0',
#    'mallInfo': '0',
#    'coordiScr': '0',
#    'isCoordiCtg': '0',
#    'isAdult': '0',
#    'hasVideo': '0',
#    'isHotDeal': '0',
#    'purchaseCnt': '4908',
#    'mblSimImgSgntCnt': '24',
#    'priceUnit': 'KRW',
#    'tvProdInfo': '^^',
#    'mobileLowPrice': '14200',
#    'mallProductId': '5035940311',
#    'imgColorCd': '1',
#    'lowPrice': '14200',
#    'price': '14200',
#    'dummy': '2020-11-11 01:10:05',
#    'imgSgnt': '6791827694731627248405713690',
#    'lstRcvYmdt': '20201111',
#    'checkOutReviewCount': '0',
#    'mallNo': '1205162',
# ...

# %%
#중간에 0이 상품 n번째 수 여기서 for문 사용
json.loads(a2)['props']['pageProps']['initialState']['products']['list'][0]['item']
# Out:
# {'collection': 'product',
#  'purchaseConditionInfos': None,
#  'rank': '6',
#  'adId': 'nad-a001-02-000000101467780',
#  'id': '82580461253',
#  'parentId': '82580461253',
#  'productTitle': '국산 식약처인증 KF-AD 비말차단마스크 개별포장 일회용 화이트 블랙 대형 50매',
#  'mallName': '라스트무버',
#  'isBrandStore': '0',
#  'isNaverPay': '1',
#  'isMblNaverPay': '1',
#  'nPayPcType': '2',
#  'nPayMblType': '2',
#  'saleTp': '0',
#  'mallInfo': '0',
#  'coordiScr': '0',
#  'isCoordiCtg': '0',
#  'isAdult': '0',
#  'hasVideo': '0',
#  'isHotDeal': '0',
#  'purchaseCnt': '4908',
#  'mblSimImgSgntCnt': '24',
#  'priceUnit': 'KRW',
#  'tvProdInfo': '^^',
#  'mobileLowPrice': '14200',
#  'mallProductId': '5035940311',
#  'imgColorCd': '1',
#  'lowPrice': '14200',
#  'price': '14200',
#  'dummy': '2020-11-11 01:10:05',
#  'imgSgnt': '6791827694731627248405713690',
#  'lstRcvYmdt': '20201111',
#  'checkOutReviewCount': '0',
#  'mallNo': '1205162',
#  'category2Name': '건강관리용품',
#  'descriptionOrder': 'C12003|RV',
# ...

# %%
for i in range(48):
    print(json.loads(a2)['props']['pageProps']['initialState']['products']['list'][i]['item']['productTitle'])
# Out:
# 국산 식약처인증 KF-AD 비말차단마스크 개별포장 일회용 화이트 블랙 대형 50매
# 국산 닥터N마스크 일회용 덴탈 마스크 50매
# 국산 잇템 덴탈 마스크 50매 일회용 MB필터 FDA승인
# 식약처인증 국산 3중 일회용 덴탈마스크 50매
# 블루인더스 블루본 KF80 소형 마스크
# 국산 KF94 하코 마스크 캐릭터 끈조절 초소형 소소형 소형 아기 유아 미세먼지 황사
# 어린이 소형 비말 50매, KFAD KF80 KF94마스크 덴탈 신생아 초소형 웰킵스
# 마스크프로 3D 입체형 일회용 덴탈 마스크 50매 비말 귀편한 새부리형 스트랩
# 식약처 KF-AD 비말차단마스크 50매 의약외품 덴탈 일회용 코로나19 KF94 KF80
# 가드플러스 일회용 마스크 50매 MB필터 코로나19 덴탈 비말 블루 핑크 스트랩 목걸이
# 아이숲 KF80 소형 마스크 50매
# 휴안청 국산 KF94 마스크 검정 블랙 중형 대형 90매 식약처허가 황사 방역 마스크
# 이지숨 KF94 황사 미세먼지 방역 마스크
# 엄마가 찾는 그 3D 유아 아동 어린이 귀가편한 소형 초소형 덴탈 돌 아기 초등학생 캐릭터 입체 키즈 영아 6개월 베이비 새부리형 일회용 신생아 3중필터 침방울 비말 차단 마스크
# 미마 보건용 마스크 KF94
# KF80 KF94 마스크 소형 중형 대형 블랙 화이트 100매이상 대량전문 당일출고
# KF94 KF80 KFAD 힐메이드 중형 대형마스크 블랙 화이트 100매이상 당일발송
# 당일출고 유한킴벌리 어린이마스크 덴탈마스크 36매입
# 국산 KF94 KF80 KF-AD 비말 차단 마스크 새부리형 대형 소형 1매 100매
# 애니가드 고래 마스크 50매 KC인증 어린이 소형 초소형 유아용 아동용
# 국내생산 쉼표리빙 새부리형 KF94 마스크 50매 미세먼지 개별포장 화이트 블랙 그레이 대형 소형
# KF80 94 소형 유아 어린이 아동 일회용 블루인더스 블루본 새부리형 마스크 국산
# 언더아머 UA 스포츠 마스크 블랙 운동용 축구 야구선수
# ...

# %%
from pandas import DataFrame
a3 = json.loads(a2)['props']['pageProps']['initialState']['products']['list'][0]['item']

# %%
DataFrame(a3)
# Out:
#                    collection purchaseConditionInfos rank  \
# seq                   product                   None    6
# prodCnt               product                   None    6
# name                  product                   None    6
# bizplBaseAddr         product                   None    6
# bizplDtlAddr          product                   None    6
# businessNo            product                   None    6
# onmktRegisterNo       product                   None    6
# mallIntroduction      product                   None    6
# mallLogos             product                   None    6
# mallGrade             product                   None    6
# goodService           product                   None    6
# talkAccountId         product                   None    6
# eventScheduledCont    product                   None    6
# adsrType              product                   None    6
# naverPay              product                   None    6
#
# ...
