# %%
import easygui
path = easygui.fileopenbox()

# %%
import pandas as pd
test = pd.read_csv(path)

# %%
test = test['contents']

# %%
from tqdm import tnrange
a = []
for i in tnrange(len(test['contents'])):
    if len(test['contents'][i]) > 5000:
        print(i)
    else:
        a.append(pypapago2('영어',test['contents'][i]))

# %%
from multiprocessing import Pool 
import tqdm
import time
import workers 

r = []
if __name__ == '__main__': 
    with Pool(10) as p:
        r = list(tqdm.tqdm(p.imap(workers.pypapago2,[test2[i] for i in range(100)]),total=100))
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]
#
#
#
#
#
#
#   1%|▊                                                                                 | 1/100 [00:03<05:32,  3.36s/it]
#
#
#
#
#
#
#   4%|███▎                                                                              | 4/100 [00:04<03:57,  2.47s/it]
#
#
#
#
#
#
#  12%|█████████▋                                                                       | 12/100 [00:05<02:35,  1.77s/it]
#
#
#
#
#
#
#  27%|█████████████████████▊                                                           | 27/100 [00:06<01:31,  1.26s/it]
#
#
#
#
#
#
#  33%|██████████████████████████▋                                                      | 33/100 [00:06<00:59,  1.13it/s]
#
#
#
#
#
#
#  35%|████████████████████████████▎                                                    | 35/100 [00:06<00:43,  1.49it/s]
#
#
#
#
#
#
# ...

# %%
path2 = easygui.fileopenbox()
test2 = pd.read_csv(path2)

# %%
test2 = test2['Contents']

# %%
from afinn import Afinn

afn = Afinn(emoticons=True)

for i in range(len(r)):
    print(test2[i])
    print(afn.score(r[i]))
# Out:
# 착한 가격에 최고의 품질입니다. 굳이 비싼 돈주고 다른 제품 쓸 필요가 없는 것 같습니다. 전 몇년째 여기서만 쓰고 있습니다. 최고이십니다
# 11.0
# 품질 포장 배송  모두우수하네요 굿입니다
# 8.0
# 직접 사용 해보셔요
# 0.0
# 날 면도를 한 달에 10회 미만으로 하는
# 제 입장에서 와이즐리는 합리적인 소비라 생각합니다.
# 다만, 아직도 날 면도시 상처가 납니다.
#  늘 깨끗한 피부일 순 없기에 인중이나
# 턱 주변에 뾰루지가 생겼기 때문이지요.
# 절삭력을 중시한 제품 연구도 좋지만
# '와이즐리 면도기를 쓰면 상처가 안나고
# 면도가 가능하다'라는 인식이 생길 수 있게끔
# 제품 연구도 해주시면 좋겠습니다.
#
# 또한, 분사형으로 된 면도날 세척용액도 만들어
# 주시면 좋겠습니다.
# (한 번 쓴 면도날을 바로 버리긴 아까워서
# 3~4회는 쓴답니다.)
# 9.0
# 무게감 그립감 면도감 모두 탁월합니다~
# 3.0
# 선물용으로 부담스럽지 않아 좋습니다
# 5.0
# 가성비 짱입니다  최고에요
# 8.0
# 타사 다른 비슷 제품도 써오고 있었는데 우연한 기회에 와이즐리를 접했는데 확실히 절삭력도 좋고 면도후에 피부 트러블도 좋아져서 대만족 입니다~^^
# 4.0
# 와이즐리 제품 아주 만족합니다.  한가지 아쉬운점은  면도탈과 면도기 부착 부분에 청소가 어렵네요.  이 문제는 다른 회사 제품들도 마찬가지지만..와이즐리가 해결해 주시면 좋겠네요 ^^
# 5.0
# 가격대비 가성비 좋아요
# 5.0
# 레이지 소사이어티 새로 나왓다길래 써봣는데 역시 와이즐리 따라오려면 멀엇네요 레이지 쓸때는 피부 상처난 적이 한두번이 아니엇는데 ㄷㅏ시 와이즐리 쓰니 상처 전혀 안나고 부드럽게 면도 됩니다. 와이즐리 최고!!!
# -2.0
# 디자인도 마음에 들고 저렴한 가격이 마음에 듭니다.
# 한 가지 아쉬운 점이 있어 글 올립니다
#
# ...

# %%
import pandas as pd
df = pd.read_csv('E:/[python]/5. [python] 자연어/data/daum/2020/20200101.csv')
url = df['url']

# %%
from multiprocessing import Pool 
import tqdm
import time
import workers 
if __name__ == '__main__': 
    with Pool(10) as p:
        r = list(tqdm.tqdm(p.imap(workers.review_num,[url[i] for i in range(10000)]),total=10000))

# %%
pd.set_option("display.max_rows", None , "display.max_columns", None)
DataFrame(r)[DataFrame(r)['commentCount'] > 1]

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://news.v.daum.net/v/20201104090600325'
resp = requests.get(url,verify=False)
soup = BeautifulSoup(resp.text,'lxml')
client_id = soup.select('.alex-area')[0]['data-client-id']
tar = 'https://comment.daum.net/oauth/token?grant_type=alex_credentials&client_id=' + client_id
headers= {
    'Referer':url,
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
}

requests.get(tar,headers=headers,verify=False).text

# %%
# 댓글을 달 빈 리스트를 생성합니다.
List=[]
# 라이브러리를 로드합니다.
from bs4 import BeautifulSoup
import requests
import re
import sys
import pprint

# 네이버 뉴스 url을 입력합니다.
url="http://news.naver.com/main/hotissue/read.nhn?mid=hot&sid1=100&cid=1079165&iid=2780573&oid=001&aid=0010079145&ptype=052"

oid=url.split("oid=")[1].split("&")[0]
aid=url.split("aid=")[1]
page=1    
header = {
    "User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36",
    "referer":url,
    
} 
while True :
    c_url="https://apis.naver.com/commentBox/cbox/web_neo_list_jsonp.json?ticket=news&templateId=default_society&pool=cbox5&_callback=jQuery1707138182064460843_1523512042464&lang=ko&country=&objectId=news"+oid+"%2C"+aid+"&categoryId=&pageSize=20&indexSize=10&groupId=&listType=OBJECT&pageType=more&page="+str(page)+"&refresh=false&sort=FAVORITE" 
# 파싱하는 단계입니다.
    r=requests.get(c_url,headers=header,verify=False)
    cont=BeautifulSoup(r.content,"html.parser")    
    total_comm=str(cont).split('comment":')[1].split(",")[0]
   
    match=re.findall('"contents":([^\*]*),"userIdNo"', str(cont))
# 댓글을 리스트에 중첩합니다.
    List.append(match)
# 한번에 댓글이 20개씩 보이기 때문에 한 페이지씩 몽땅 댓글을 긁어 옵니다.
    if int(total_comm) <= ((page) * 20):
        break
    else : 
        page+=1


# 여러 리스트들을 하나로 묶어 주는 함수입니다.
def flatten(l):
    flatList = []
    for elem in l:
        # if an element of a list is a list
        # iterate over this list and add elements to flatList 
        if type(elem) == list:
            for e in elem:
                flatList.append(e)
        else:
            flatList.append(elem)
    return flatList


# 리스트 결과입니다.
flatten(List)

# %%
flatten(List)

# %%
import hashlib
def get_md5(s):
    return hashlib.md5(bytes(s, encoding='utf-8')).hexdigest()

# %%
import time
int(time.time()*1000)

# %%
timestamp

# %%
import hmac
import string
import hashlib
import base64
import time

from base64 import b64decode, b64encode


# https://stackoverflow.com/questions/48303874/why-python-and-node-jss-hmac-result-is-different-in-this-code
# Why Python and Node.js's HMAC result is different in this code?

timestamp = int(time.time()*1000)

key = ("v1.5.2_0d13cb6cf4").encode('utf-8')
msg = '3cb80585-364a-4b66-b3a4-b778b28df550'+\
        "\n"+\
        'https://papago.naver.com/apis/n2mt/translate' +\
        "\n"+\
        str(timestamp)

hmac_result = hmac.new(key, msg.encode('utf-8'), hashlib.md5)

print(b64encode(hmac_result.digest()).decode('utf-8'))
print(base64.b64encode(hmac_result.digest()).decode('utf-8'))

# %%
from hashlib import blake2s
from base64 import b64decode, b64encode
orig_key = b64decode(b'Rm5EPJai72qcK3RGBpW3vPNfZy5OZothY+kHY6h21KM=')
orig_key

# %%
import hmac
import string
import hashlib
import base64

secret = 'PYPd1Hv4J6'
message = '1515928475.417'
key = base64.b64encode(secret.encode('utf-8'))

hmac_result = hmac.new(key, message.encode('utf-8'), hashlib.sha512)
print(base64.b64encode(hmac_result.digest()))

# %%
key = 'v1.5.2_0d13cb6cf4'
msh = '3cb80585-364a-4b66-b3a4-b778b28df550' + '\n' +  'https://papago.naver.com/apis/n2mt/translate' + '\n' + '1604534834981'

# %%
import hmac, hashlib
hmac.new('key', 'msg').hexdigest()
